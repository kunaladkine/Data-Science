# %%
#number of approaches to create an series 
import pandas as pd
a=10
s=pd.Series(a)
print(s)
# Out:
# 0    10
# dtype: int64

# %%
a=23.4
s=pd.Series(a)
print(s)
# Out:
# 0    23.4
# dtype: float64

# %%
s="Hello"
a=pd.Series(s)
print(a)
# Out:
# 0    Hello
# dtype: object

# %%
a=[10,20,30,40,50]
s=pd.Series(a)
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
a=[20,"Hello",33.43,32]
s=pd.Series(a)
print(s)
# Out:
# 0       20
# 1    Hello
# 2    33.43
# 3       32
# dtype: object

# %%
s[0]
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_10832\243613605.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s[0]
# 20

# %%
s[2]
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_10832\2635755408.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s[2]
# 33.43

# %%
a=[20,"Hello",33.43,32]
s=pd.Series(a,index=["a","b","c","d"])
print(s)
# Out:
# a       20
# b    Hello
# c    33.43
# d       32
# dtype: object

# %%
s["a"]
# Out:
# 20

# %%
s["c"]
# Out:
# 33.43

# %%
s["d"]
# Out:
# 32

# %%
s[0]
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_10832\243613605.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s[0]
# 20

# %%
s["b"]
# Out:
# 'Hello'

# %%
#creating series object with index name
a=[20,"Hello",33.43,32]
s=pd.Series(a,index=[1,2,3,4])
print(s)
# Out:
# 1       20
# 2    Hello
# 3    33.43
# 4       32
# dtype: object

# %%
s[1]
# Out:
# 20

# %%
s[2]
# Out:
# 'Hello'

# %%
s[3]
# Out:
# 33.43

# %%
s[4]
# Out:
# 32

# %%
#creating series object wwith list in list 
a=[[10,"RS"],[20,"SS"],[30,"SR"]]
s=pd.Series(a)
print(s)
# Out:
# 0    [10, RS]
# 1    [20, SS]
# 2    [30, SR]
# dtype: object

# %%
#reversing a list
s[::-1]
# Out:
# 2    [30, SR]
# 1    [20, SS]
# 0    [10, RS]
# dtype: object

# %%
s[0]
# Out:
# [10, 'RS']

# %%
s[2]
# Out:
# [30, 'SR']

# %%
#in list no negative indexing will done while getting the value
s[-1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:413, in RangeIndex.get_loc(self, key)
#     412 try:
# --> 413     return self._range.index(new_key)
#     414 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 s[-1]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#    1125 if is_iterator(key):
#
# ...

# %%
#creating series object with list in list with index value
a=[[10,"RS"],[20,"SS"],[30,"SR"]]
s=pd.Series(a,index=[1,2,3])
print(s)
# Out:
# 1    [10, RS]
# 2    [20, SS]
# 3    [30, SR]
# dtype: object

# %%
#accesing the value with the index 
s[1]
# Out:
# [10, 'RS']

# %%
s[2]
# Out:
# [20, 'SS']

# %%
s[3]
# Out:
# [30, 'SR']

# %%
a=[[10,"RS"],[20,"SS"],[30,"SR"]]
s=pd.Series(a,index=["a","b","c"])
print(s)
# Out:
# a    [10, RS]
# b    [20, SS]
# c    [30, SR]
# dtype: object

# %%
s["a"]
# Out:
# [10, 'RS']

# %%
s["b"]
# Out:
# [20, 'SS']

# %%
s["c"]
# Out:
# [30, 'SR']

# %%
#creating index with the tuple in list
a=([10,"RS"],[20,"SS"],[30,"SR"])
s=pd.Series(a,index=["a","b","c"])
print(s)
# Out:
# a    [10, RS]
# b    [20, SS]
# c    [30, SR]
# dtype: object

# %%
s["a"]
# Out:
# [10, 'RS']

# %%
s["b"]
# Out:
# [20, 'SS']

# %%
s["c"]
# Out:
# [30, 'SR']

# %%
s[::-1]
# Out:
# c    [30, SR]
# b    [20, SS]
# a    [10, RS]
# dtype: object

# %%
s={1:22,2:33,3:32,4:54}
a=pd.Series(s)
print(a)
# Out:
# 1    22
# 2    33
# 3    32
# 4    54
# dtype: int64

# %%
s[1]
# Out:
# 22

# %%
s[2]
# Out:
# 33

# %%
s[4]
# Out:
# 54

# %%
s={1:22,2:33,3:32,4:54}
a=pd.Series(s,index=["a","b","c","d"])
print(a)
# Out:
# a   NaN
# b   NaN
# c   NaN
# d   NaN
# dtype: float64
