# %%
import numpy as np

# %%
#create 2 array for this 
a=np.array([1,2,3,4]).reshape(2,2)
b=np.array([10,20,30,40]).reshape(2,2)
print("----------------------------")
print("Matrix 1")
print(a)
print("----------------------------")
print("Matrix 2")
print(b)
print("-----------------------------")
# Out:
# ----------------------------
# Matrix 1
# [[1 2]
#  [3 4]]
# ----------------------------
# Matrix 2
# [[10 20]
#  [30 40]]
# -----------------------------

# %%
#matrix operation to be performed
#by using elementwise matrix operation
c=np.add(a,b)
print(c)
# Out:
# [[11 22]
#  [33 44]]

# %%
c=np.add(b,a)
print(c)
# Out:
# [[11 22]
#  [33 44]]

# %%
#by using arithimetic operator = +
c=a+b
print(c)
# Out:
# [[11 22]
#  [33 44]]

# %%
c=b+a
print(c)
# Out:
# [[11 22]
#  [33 44]]

# %%
#matrix operation to be performed
#by using elementwise matrix operation
c=np.subtract(a,b)
print(c)
# Out:
# [[ -9 -18]
#  [-27 -36]]

# %%
c=a-b
print(c)
# Out:
# [[ -9 -18]
#  [-27 -36]]

# %%
c=b-a
print(c)
# Out:
# [[ 9 18]
#  [27 36]]

# %%
#matrix operation to be performed
#by using elementwise matrix operation
c=np.multiply(a,b)
print(c)
# Out:
# [[ 10  40]
#  [ 90 160]]

# %%
c=a*b
print(c)
# Out:
# [[ 10  40]
#  [ 90 160]]

# %%
c=b*a
print(c)
# Out:
# [[ 10  40]
#  [ 90 160]]

# %%
#matrix operation to be performed
#by using elementwise matrix operation
c=np.dot(a,b)
print(c)
# Out:
# [[ 70 100]
#  [150 220]]

# %%
#matrix operation to be performed
#by using elementwise matrix operation
c=np.matmul(a,b)
print(c)
# Out:
# [[ 70 100]
#  [150 220]]

# %%
#matrix operation to be performed
#by using elementwise matrix operation
c=np.divide(a,b)
print(c)
# Out:
# [[0.1 0.1]
#  [0.1 0.1]]

# %%
c=np.divide(b,a)
print(c)
# Out:
# [[10. 10.]
#  [10. 10.]]

# %%
c=a/b
print(c)
# Out:
# [[0.1 0.1]
#  [0.1 0.1]]

# %%
c=b/a
print(c)
# Out:
# [[10. 10.]
#  [10. 10.]]

# %%
#matrix operation to be performed
#by using elementwise matrix operation
c=np.floor_divide(a,b)
print(c)
# Out:
# [[0 0]
#  [0 0]]

# %%
c=np.floor_divide(b,a)
print(c)
# Out:
# [[10 10]
#  [10 10]]

# %%
c=a//b
print(c)
# Out:
# [[0 0]
#  [0 0]]

# %%
c=b//a
print(c)
# Out:
# [[10 10]
#  [10 10]]

# %%
#matrix operation to be performed
#by using elementwise matrix operation
c=np.mod(a,b)
print(c)
# Out:
# [[1 2]
#  [3 4]]

# %%
c=np.mod(b,a)
print(c)
# Out:
# [[0 0]
#  [0 0]]

# %%
c=a%b
print(c)
# Out:
# [[1 2]
#  [3 4]]

# %%
c=b%a
print(c)
# Out:
# [[0 0]
#  [0 0]]

# %%
#matrix operation to be performed
#by using elementwise matrix operation
c=np.power(a,b)
print(c)
# Out:
# [[              1         1048576]
#  [205891132094649               0]]

# %%
c=np.power(b,a)
print(c)
# Out:
# [[     10     400]
#  [  27000 2560000]]

# %%
c=a**b
print(c)
# Out:
# [[              1         1048576]
#  [205891132094649               0]]

# %%
c=b**a
print(c)
# Out:
# [[     10     400]
#  [  27000 2560000]]
