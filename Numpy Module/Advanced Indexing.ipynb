# %%
import numpy as np
a=np.array([10,20,30,40,50,60,70,80,90,15,25,35])
print("-------------------------------------------------")
print("Content of a")
print(a)
print("Dimension of a=",a.ndim)
print("Shape of a=",a.shape)
print("Size of a=",a.size)
print("-------------------------------------------------")
# Out:
# -------------------------------------------------
# Content of a
# [10 20 30 40 50 60 70 80 90 15 25 35]
# Dimension of a= 1
# Shape of a= (12,)
# Size of a= 12
# -------------------------------------------------

# %%
#to get the index value of 10,40,50
lst=[0,3,4]
a[lst]
# Out:
# array([10, 40, 50])

# %%
a[[0,3,4]]
# Out:
# array([10, 40, 50])

# %%
a[[0,3,4]]
# Out:
# array([10, 40, 50])

# %%
import numpy as np
from numpy import random as r
lst=r.randint(0,25,size=10)
print(lst)
# Out:
# [17  9 11 23 14 21 23 23 14 24]

# %%
for value, index in enumerate(lst):
    print(value,"--->",index)
# Out:
# 0 ---> 17
# 1 ---> 9
# 2 ---> 11
# 3 ---> 23
# 4 ---> 14
# 5 ---> 21
# 6 ---> 23
# 7 ---> 23
# 8 ---> 14
# 9 ---> 24

# %%
lst[[2,5]]
# Out:
# array([11, 21], dtype=int32)

# %%
b=[0,3,9]
lst[b]
# Out:
# array([17, 23, 24], dtype=int32)

# %%
rv=r.randint(1,100,size=(5,5))
print(rv)
# Out:
# [[68 39 47  7 89]
#  [36 77 66 51 41]
#  [46 56 20 82 16]
#  [66 42 90 14 45]
#  [12 52 59 91 68]]

# %%
print("size of array=",a.size)
print("shape of array =",a.shape)
print("Dim of array=",a.ndim)
# Out:
# size of array= 12
# shape of array = (12,)
# Dim of array= 1

# %%
#Steps for Advanced Indexing with 2-D
#Step-1: Identify the Row Indices of Elements and places them in Traditional Python Object/ndarray object
#Step-2: Identify the Column Indices of Elements and places them in Traditional Python Object/ndarray object
#Step-3: Pass Row Indices and Column Indices to ndarray Object
